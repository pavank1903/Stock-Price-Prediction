# %% [markdown]
# # New Section

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
d=pd.read_csv('/content/nifty_500.csv')
print(d)
# Out:
#                                          Company Name      Open      High  \
# 0                                       3M India Ltd.     22.30     22.30
# 1                                    Aarti Drugs Ltd.  21950.00  21999.00
# 2                               Aavas Financiers Ltd.    400.50    401.80
# 3                                      ABB India Ltd.   2260.35   2311.50
# 4                                   Abbott India Ltd.  18700.40  19200.00
# ..                                                ...       ...       ...
# 495                Zee Entertainment Enterprises Ltd.    273.15    273.55
# 496                           Zensar Technolgies Ltd.   7748.00   7900.00
# 497  ZF Commercial Vehicle Control Systems India Ltd.     54.15     56.70
# 498                                       Zomato Ltd.    356.90    364.05
# 499                           Zydus Lifesciences Ltd.   1635.00   1635.00
#
#           Low  Previous Close  Last Traded Price   Change  Percentage Change  \
# ...

# %%
d.head(5)
# Out:
#             Company Name      Open     High       Low  Previous Close  \
# 0          3M India Ltd.     22.30     22.3     21.50           22.00
# 1       Aarti Drugs Ltd.  21950.00  21999.0  21126.05        21854.05
# 2  Aavas Financiers Ltd.    400.50    401.8    394.10          403.85
# 3         ABB India Ltd.   2260.35   2311.5   2260.35         2300.90
# 4      Abbott India Ltd.  18700.40  19200.0  18605.00        18760.40
#
#    Last Traded Price   Change  Percentage Change  Share Volume  \
# 0              21.55    -0.45              -2.05       1040692
# 1           21575.00  -279.05              -1.28          4159
# 2             400.00    -3.85              -0.95         31782
# 3            2280.00    -20.9              -0.91         97053
# 4           19199.80    439.4               2.34         12396
#
#    Value (Indian Rupee)  52 Week High  52 Week Low  365 Day Percentage Change  \
# 0          2.264546e+07         35.80        18.85                      26.00
# ...

# %%
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 14 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Company Name               500 non-null    object
#  1   Open                       500 non-null    float64
#  2   High                       500 non-null    float64
#  3   Low                        500 non-null    float64
#  4   Previous Close             500 non-null    float64
#  5   Last Traded Price          500 non-null    float64
#  6   Change                     500 non-null    object
#  7   Percentage Change          500 non-null    float64
#  8   Share Volume               500 non-null    int64
#  9   Value (Indian Rupee)       500 non-null    float64
#  10  52 Week High               500 non-null    float64
#  11  52 Week Low                500 non-null    float64
#  12  365 Day Percentage Change  500 non-null    float64
# ...

# %%
df = pd.DataFrame(d, columns=["Value (Indian Rupee)", "Share Volume"])
df.plot(x="Share Volume", y=["Value (Indian Rupee)"], figsize=(90, 8))
plt.show()

# %%
df = pd.DataFrame(d, columns=["Value (Indian Rupee)", "Previous Close"])
df.plot(x="Previous Close", y=["Value (Indian Rupee)"], figsize=(9, 8))
plt.show()

# %%
df = pd.DataFrame(d, columns=["365 Day Percentage Change", "Previous Close"])
df.plot(x="Previous Close", y=["365 Day Percentage Change"], figsize=(9, 8))
plt.show()

# %%
d['Open'].plot(figsize=(16,6))
# Out:
# <Axes: >

# %%
plt.figure(figsize=(20,12))
plt.subplot(2,1,1)
plt.title('stock price')
plt.plot(d.High,label='Previous Close')
plt.legend()
plt.show()

# %%
d.to_csv("cleaned_data")

# %%
d.corr()
# Out:
#                                Open      High       Low  Previous Close  \
# Open                       1.000000  0.999913  0.999923        0.999983
# High                       0.999913  1.000000  0.999972        0.999948
# Low                        0.999923  0.999972  1.000000        0.999959
# Previous Close             0.999983  0.999948  0.999959        1.000000
# Last Traded Price          0.999832  0.999973  0.999957        0.999890
# Percentage Change          0.035287  0.038080  0.037664        0.035271
# Share Volume              -0.072968 -0.072515 -0.072915       -0.072819
# Value (Indian Rupee)       0.015589  0.015497  0.013784        0.015855
# 52 Week High               0.990766  0.990132  0.990253        0.990579
# 52 Week Low                0.994696  0.994540  0.994780        0.994868
# 365 Day Percentage Change  0.059272  0.059323  0.058828        0.059295
# 30 Day Percentage Change   0.077533  0.076248  0.076036        0.077168
#
# ...

# %%
d.cov()
# Out:
#                                    Open          High           Low  \
# Open                       1.999029e+07  2.047972e+07  1.984948e+07
# High                       2.047972e+07  2.098480e+07  2.033825e+07
# Low                        1.984948e+07  2.033825e+07  1.971271e+07
# Previous Close             2.003729e+07  2.052895e+07  1.989721e+07
# Last Traded Price          2.027954e+07  2.078080e+07  2.014078e+07
# Percentage Change          3.492162e+02  3.861173e+02  3.701472e+02
# Share Volume              -3.071857e+09 -3.127772e+09 -3.048243e+09
# Value (Indian Rupee)       3.025025e+11  3.081160e+11  2.656198e+11
# 52 Week High               2.540218e+07  2.600974e+07  2.521214e+07
# 52 Week Low                1.714143e+07  1.755988e+07  1.702343e+07
# 365 Day Percentage Change  8.697700e+03  8.919057e+03  8.572437e+03
# 30 Day Percentage Change   3.110241e+03  3.133877e+03  3.028945e+03
#
#                            Previous Close  Last Traded Price  \
# ...

# %%
for column in d.columns:
  print(d[column].value_counts())
  print("*"*20)
# Out:
# 3M India Ltd.                           1
# NLC India Ltd.                          1
# PCBL Ltd.                               1
# One 97 Communications Ltd.              1
# Page Industries Ltd.                    1
#                                        ..
# GMM Pfaudler Ltd.                       1
# Glenmark Life Sciences Ltd.             1
# Glenmark Pharmaceuticals Ltd.           1
# Glaxosmithkline Pharmaceuticals Ltd.    1
# Zydus Lifesciences Ltd.                 1
# Name: Company Name, Length: 500, dtype: int64
# ********************
# 148.35     2
# 550.00     2
# 2995.00    2
# 39.40      2
# 670.00     2
#           ..
# 566.00     1
# 34.00      1
# 4355.00    1
# 441.00     1
# 1635.00    1
# Name: Open, Length: 491, dtype: int64
# ********************
# 96.40      2
# 425.95     2
# 603.00     2
# 1233.45    2
# 39.50      2
#           ..
# 582.00     1
# 34.75      1
# 4372.00    1
# 444.50     1
# 1635.00    1
# Name: High, Length: 494, dtype: int64
# ...

# %%
d.describe()
# Out:
#                Open          High           Low  Previous Close  \
# count    500.000000    500.000000    500.000000      500.000000
# mean    1524.962100   1552.904500   1503.261500     1527.086500
# std     4471.050598   4580.916515   4439.900013     4481.640096
# min        6.750000      6.950000      6.700000        6.850000
# 25%      214.850000    220.862500    210.462500      216.500000
# 50%      550.550000    568.200000    546.300000      554.275000
# 75%     1401.125000   1420.312500   1385.262500     1408.137500
# max    70300.000000  72500.000000  70300.000000    70800.900000
#
#        Last Traded Price  Percentage Change  Share Volume  \
# count         500.000000         500.000000  5.000000e+02
# mean         1536.113000           0.361800  2.585210e+06
# std          4536.507027           2.213474  9.415813e+06
# min             6.800000         -14.830000  1.507000e+03
# 25%           214.537500          -0.820000  7.720225e+04
# ...

# %%
d['Share Volume'].value_counts()
# Out:
# 1040692    1
# 5571985    1
# 536946     1
# 547189     1
# 3069693    1
#           ..
# 4338629    1
# 14737      1
# 15000      1
# 398227     1
# 10803      1
# Name: Share Volume, Length: 500, dtype: int64

# %%
d.shape
# Out:
# (500, 14)

# %%
d
# Out:
#                                          Company Name      Open      High  \
# 0                                       3M India Ltd.     22.30     22.30
# 1                                    Aarti Drugs Ltd.  21950.00  21999.00
# 2                               Aavas Financiers Ltd.    400.50    401.80
# 3                                      ABB India Ltd.   2260.35   2311.50
# 4                                   Abbott India Ltd.  18700.40  19200.00
# ..                                                ...       ...       ...
# 495                Zee Entertainment Enterprises Ltd.    273.15    273.55
# 496                           Zensar Technolgies Ltd.   7748.00   7900.00
# 497  ZF Commercial Vehicle Control Systems India Ltd.     54.15     56.70
# 498                                       Zomato Ltd.    356.90    364.05
# 499                           Zydus Lifesciences Ltd.   1635.00   1635.00
#
#           Low  Previous Close  Last Traded Price   Change  Percentage Change  \
# ...

# %%
d.drop(columns=['Value (Indian Rupee)','365 Day Percentage Change'],inplace=True)

# %%
d.drop(columns=['Change'],inplace=True)

# %% [markdown]
# Cleaned data

# %%
d.head()
# Out:
#             Company Name      Open     High       Low  Previous Close  \
# 0          3M India Ltd.     22.30     22.3     21.50           22.00
# 1       Aarti Drugs Ltd.  21950.00  21999.0  21126.05        21854.05
# 2  Aavas Financiers Ltd.    400.50    401.8    394.10          403.85
# 3         ABB India Ltd.   2260.35   2311.5   2260.35         2300.90
# 4      Abbott India Ltd.  18700.40  19200.0  18605.00        18760.40
#
#    Last Traded Price  Percentage Change  Share Volume  52 Week High  \
# 0              21.55              -2.05       1040692         35.80
# 1           21575.00              -1.28          4159      27800.00
# 2             400.00              -0.95         31782        749.75
# 3            2280.00              -0.91         97053       2487.85
# 4           19199.80               2.34         12396      23934.45
#
#    52 Week Low  30 Day Percentage Change
# 0        18.85                     26.00
# 1     17273.00                      8.22
# ...

# %%
d.drop(columns=('Company Name'))
# Out:
#          Open      High       Low  Previous Close  Last Traded Price  \
# 0       22.30     22.30     21.50           22.00              21.55
# 1    21950.00  21999.00  21126.05        21854.05           21575.00
# 2      400.50    401.80    394.10          403.85             400.00
# 3     2260.35   2311.50   2260.35         2300.90            2280.00
# 4    18700.40  19200.00  18605.00        18760.40           19199.80
# ..        ...       ...       ...             ...                ...
# 495    273.15    273.55    268.40          272.10             270.00
# 496   7748.00   7900.00   7525.30         7716.60            7680.00
# 497     54.15     56.70     52.55           53.85              56.00
# 498    356.90    364.05    354.30          357.00             364.00
# 499   1635.00   1635.00   1605.00         1636.85            1627.00
#
#      Percentage Change  Share Volume  52 Week High  52 Week Low  \
# 0                -2.05       1040692         35.80        18.85
# ...

# %%
d.to_csv("Cleaned_data.csv")

# %%
x=d.drop(columns=['Share Volume'])
y=d['Share Volume']

# %%
from sklearn.model_selection import train_test_split

from sklearn.linear_model import LinearRegression, Lasso, Ridge 
from sklearn.preprocessing import OneHotEncoder, StandardScaler

from sklearn.compose import make_column_transformer
from sklearn.pipeline import make_pipeline 
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt
from sklearn import metrics

# %% [markdown]
# Applying LinearRegression

# %%
X = d.drop('Share Volume', axis=1) 
y = d['Share Volume']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1)


regressor = LinearRegression()


regressor.fit(X_train, y_train)


y_pred = regressor.predict(X_test)


print("Mean Absolute Error:", metrics.mean_absolute_error(y_test, y_pred))
print("Mean Squared Error:", metrics.mean_squared_error(y_test, y_pred))
print("Root Mean Squared Error:", np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# Mean Absolute Error: 3675482.1620659065
# Mean Squared Error: 34144471486405.92
# Root Mean Squared Error: 5843327.090485858

# %% [markdown]
# Decision Trees

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
X = d.drop('Share Volume', axis=1) 
y = d['Share Volume'] 


X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1)


clf = DecisionTreeClassifier()


clf = clf.fit(X_train,y_train)


y_pred = clf.predict(X_test)


print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.0

# %% [markdown]
# KNN

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
X = d.drop('Share Volume', axis=1) 
y = d['Share Volume'] 


X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1)


k = 3
clf = KNeighborsClassifier(n_neighbors=k)

clf.fit(X_train, y_train)


y_pred = clf.predict(X_test)

print("Accuracy:", metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.0

# %% [markdown]
# SVM

# %%
from sklearn.svm import SVC

# %%
X = d.drop('Share Volume', axis=1)
y = d['Share Volume'] 

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1)

clf = SVC(kernel='linear')


clf.fit(X_train, y_train)


y_pred = clf.predict(X_test)


print("Accuracy:", metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.0
